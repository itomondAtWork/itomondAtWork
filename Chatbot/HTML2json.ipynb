# %%
import os
import json
from bs4 import BeautifulSoup

def convert_html_to_json(input_folder, output_folder):
    # 入力フォルダ内のすべてのファイルを取得
    for filename in os.listdir(input_folder):
        if filename.endswith('.html'):
            input_path = os.path.join(input_folder, filename)

            # HTMLファイルを読み込み
            with open(input_path, 'r', encoding='utf-8') as file:
                html_content = file.read()

            # BeautifulSoupを使用してHTMLコンテンツをパース
            soup = BeautifulSoup(html_content, 'html.parser')

            # ページのテキストを抽出し、余分な改行を削除
            text_content = soup.get_text(separator='\n')
            clean_text_content = ' '.join(text_content.split())

            # クリーンなテキストをJSON形式で保存
            output_data = {
                "content": clean_text_content
            }

            # 出力ファイルパスを設定
            json_filename = os.path.splitext(filename)[0] + '.json'
            output_path = os.path.join(output_folder, json_filename)

            # JSONファイルとして保存
            with open(output_path, 'w', encoding='utf-8') as json_file:
                json.dump(output_data, json_file, ensure_ascii=False, indent=4)
            print(f"{filename} のクリーンなテキストコンテンツが {json_filename} として保存されました。")


# 入力フォルダと出力フォルダのパス
input_folder_path = 'src/HTMLs'
output_folder_path = 'src/JSONs'

# HTMLファイルを処理してJSONファイルに変換
convert_html_to_json(input_folder_path, output_folder_path)
# Out:
# BTP All IN Program.html のクリーンなテキストコンテンツが BTP All IN Program.json として保存されました。
# BTP, Analytics Cloud_ Service Map - Ad Hoc Advisory.html のクリーンなテキストコンテンツが BTP, Analytics Cloud_ Service Map - Ad Hoc Advisory.json として保存されました。
# BTP, Analytics Cloud_ Service Map - Development Infrastructure & Administrative Readiness.html のクリーンなテキストコンテンツが BTP, Analytics Cloud_ Service Map - Development Infrastructure & Administrative Readiness.json として保存されました。
# BTP, Analytics Cloud_ Service Map - New Feature Adoption Guidance.html のクリーンなテキストコンテンツが BTP, Analytics Cloud_ Service Map - New Feature Adoption Guidance.json として保存されました。
# BTP, Analytics Cloud_ Service Map - System Administrator & End User Training.html のクリーンなテキストコンテンツが BTP, Analytics Cloud_ Service Map - System Administrator & End User Training.json として保存されました。
# BTP, Analytics Cloud_ Service Maps - Success Check_ Business Goals & KPI Reporting.html のクリーンなテキストコンテンツが BTP, Analytics Cloud_ Service Maps - Success Check_ Business Goals & KPI Reporting.json として保存されました。
# BTP, Integration Suite_ Service Map - Getting Started.html のクリーンなテキストコンテンツが BTP, Integration Suite_ Service Map - Getting Started.json として保存されました。
# BTP, Integration Suite_ Service Map - Release Guidance _ Success Checks.html のクリーンなテキストコンテンツが BTP, Integration Suite_ Service Map - Release Guidance _ Success Checks.json として保存されました。
# BTP, Integration Suite_ Service Map - SCPI Service - Adoption Journeys.html のクリーンなテキストコンテンツが BTP, Integration Suite_ Service Map - SCPI Service - Adoption Journeys.json として保存されました。
# BTP, Integration Suite_ Service Map - Solution Design & Capability Advisory Check.html のクリーンなテキストコンテンツが BTP, Integration Suite_ Service Map - Solution Design & Capability Advisory Check.json として保存されました。
# BTP, Integration Suite_ Service Map - Webcasts.html のクリーンなテキストコンテンツが BTP, Integration Suite_ Service Map - Webcasts.json として保存されました。
# BTP, Integration_ Service Map - Ad Hoc Advisory.html のクリーンなテキストコンテンツが BTP, Integration_ Service Map - Ad Hoc Advisory.json として保存されました。
# CSP Engagement in Preferred Success Indirect Sales Channel.html のクリーンなテキストコンテンツが CSP Engagement in Preferred Success Indirect Sales Channel.json として保存されました。
# Customer Success Methodology (Relationship Assessment & Outcome Success Plan).html のクリーンなテキストコンテンツが Customer Success Methodology (Relationship Assessment & Outcome Success Plan).json として保存されました。
# Key Resources.html のクリーンなテキストコンテンツが Key Resources.json として保存されました。
# RESOLVED - Temporary restrictions with display widgets in Qualtrics Dashboards.html のクリーンなテキストコンテンツが RESOLVED - Temporary restrictions with display widgets in Qualtrics Dashboards.json として保存されました。
# SAP BTP_ Extension Suite - Learning.html のクリーンなテキストコンテンツが SAP BTP_ Extension Suite - Learning.json として保存されました。
# SAP BTP_ Integration Suite - Success Resources.html のクリーンなテキストコンテンツが SAP BTP_ Integration Suite - Success Resources.json として保存されました。
# SAP BTP_ Integration Suite- Release Guidance.html のクリーンなテキストコンテンツが SAP BTP_ Integration Suite- Release Guidance.json として保存されました。
# SAP BTP_ Intelligent Technologies - Learning.html のクリーンなテキストコンテンツが SAP BTP_ Intelligent Technologies - Learning.json として保存されました。
# SAP BTP_ Release Guidance Resources.html のクリーンなテキストコンテンツが SAP BTP_ Release Guidance Resources.json として保存されました。
# SAP Learning Hub, edition for SAP Preferred Success.html のクリーンなテキストコンテンツが SAP Learning Hub, edition for SAP Preferred Success.json として保存されました。
# SAP Learning Hub, Internal Edition.html のクリーンなテキストコンテンツが SAP Learning Hub, Internal Edition.json として保存されました。
# SAP Learning Hub.html のクリーンなテキストコンテンツが SAP Learning Hub.json として保存されました。
# SAP Preferred Success - Delivery Overview for CSPs.html のクリーンなテキストコンテンツが SAP Preferred Success - Delivery Overview for CSPs.json として保存されました。
# SAP Preferred Success - INTERNAL CSP Product Forums.html のクリーンなテキストコンテンツが SAP Preferred Success - INTERNAL CSP Product Forums.json として保存されました。
# SAP Preferred Success - Services Overview.html のクリーンなテキストコンテンツが SAP Preferred Success - Services Overview.json として保存されました。
# SAP Preferred Success Customer References.html のクリーンなテキストコンテンツが SAP Preferred Success Customer References.json として保存されました。
# SAP Preferred Success Deliverables.html のクリーンなテキストコンテンツが SAP Preferred Success Deliverables.json として保存されました。
# SAP Preferred Success for Business Technology Platform, expanded edition.html のクリーンなテキストコンテンツが SAP Preferred Success for Business Technology Platform, expanded edition.json として保存されました。
# SAP Preferred Success for Commerce Cloud, expanded edition.html のクリーンなテキストコンテンツが SAP Preferred Success for Commerce Cloud, expanded edition.json として保存されました。
# SAP Preferred Success for IBP for Supply Chain, expanded edition.html のクリーンなテキストコンテンツが SAP Preferred Success for IBP for Supply Chain, expanded edition.json として保存されました。
# SAP Preferred Success for SAP Business Technology Platform - Home.html のクリーンなテキストコンテンツが SAP Preferred Success for SAP Business Technology Platform - Home.json として保存されました。
# SAP Preferred Success for SAP Sales & Service Cloud, expanded edition.html のクリーンなテキストコンテンツが SAP Preferred Success for SAP Sales & Service Cloud, expanded edition.json として保存されました。
# SAP Preferred Success for SAP SuccessFactors HCM, expanded edition.html のクリーンなテキストコンテンツが SAP Preferred Success for SAP SuccessFactors HCM, expanded edition.json として保存されました。
# SAP Preferred Success Portfolio Release and Updates.html のクリーンなテキストコンテンツが SAP Preferred Success Portfolio Release and Updates.json として保存されました。
# Service Hub - SAP Business Technology Platform (BTP).html のクリーンなテキストコンテンツが Service Hub - SAP Business Technology Platform (BTP).json として保存されました。
# Service Maps - SAP Preferred Success & SAP Preferred Success, Expanded Edition.html のクリーンなテキストコンテンツが Service Maps - SAP Preferred Success & SAP Preferred Success, Expanded Edition.json として保存されました。

# %%
import os
import shutil
import pdfkit
from pptx import Presentation
from openpyxl import load_workbook

def organize_files(input_folder, output_folder):
    # 出力フォルダに必要なサブフォルダを定義
    excel_folder = os.path.join(output_folder, 'Excel')
    pdf_folder = os.path.join(output_folder, 'PDF')
    other_folder = os.path.join(output_folder, 'Other')

    # 必要なフォルダを作成
    os.makedirs(excel_folder, exist_ok=True)
    os.makedirs(pdf_folder, exist_ok=True)
    os.makedirs(other_folder, exist_ok=True)

    # 入力フォルダ内のすべてのファイルを取得
    for filename in os.listdir(input_folder):
        input_path = os.path.join(input_folder, filename)

        # ファイルかどうかを確認
        if os.path.isfile(input_path):
            # ファイル拡張子を取得
            file_extension = os.path.splitext(filename)[1].lower()

            if file_extension == '.xlsx':
                # ExcelファイルをExcelフォルダに移動
                shutil.move(input_path, os.path.join(excel_folder, filename))
                print(f"Moved {filename} to Excel folder.")

            elif file_extension == '.pptx':
                # PPTXファイルをPDFに変換してPDFフォルダに保存
                presentation = Presentation(input_path)
                pdf_path = os.path.join(pdf_folder, os.path.splitext(filename)[0] + '.pdf')
                presentation.save(pdf_path)
                shutil.move(input_path, os.path.join(pdf_folder, filename))
                print(f"Converted {filename} to PDF and moved to PDF folder.")

            elif file_extension == '.pdf':
                # PDFファイルをPDFフォルダに移動
                shutil.move(input_path, os.path.join(pdf_folder, filename))
                print(f"Moved {filename} to PDF folder.")

            else:
                # その他のファイルをOtherフォルダに移動
                shutil.move(input_path, os.path.join(other_folder, filename))
                print(f"Moved {filename} to Other folder.")

# 入力フォルダと出力フォルダのパスを指定
input_folder = './src/original_folder'
output_folder = './src'

# ファイルを整理
organize_files(input_folder, output_folder)
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting python-pptx
#   Downloading python_pptx-0.6.23-py3-none-any.whl.metadata (18 kB)
# Collecting pdfkit
#   Downloading pdfkit-1.0.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: lxml>=3.1.0 in /home/ryota/miniconda3/envs/Chatbot/lib/python3.12/site-packages (from python-pptx) (5.2.2)
# Requirement already satisfied: Pillow>=3.3.2 in /home/ryota/miniconda3/envs/Chatbot/lib/python3.12/site-packages (from python-pptx) (10.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl.metadata (2.6 kB)
# Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Downloading python_pptx-0.6.23-py3-none-any.whl (471 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 9.6 MB/s eta 0:00:00:00:01
# Downloading pdfkit-1.0.0-py3-none-any.whl (12 kB)
# Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 11.5 MB/s eta 0:00:00
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: pdfkit, XlsxWriter, et-xmlfile, python-pptx, openpyxl
# Successfully installed XlsxWriter-3.2.0 et-xmlfile-1.1.0 openpyxl-3.1.2 pdfkit-1.0.0 python-pptx-0.6.23
